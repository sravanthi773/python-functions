# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/python-functions/blob/main/python_functions_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  c=a+b
  print(c)
x=10
y=20
add(x,y)
# Out:
# 30

# %%
def sub(a,b):
  c=a-b
  print(c)
x=20
y=10
sub(x,y)
# Out:
# 10

# %%
def sub(a,b):
  print(a-b)

sub(10,20)
# Out:
# -10

# %%
def sub(a,b,c):
  print(a-b+c)

sub(10,20,30)
# Out:
# 20

# %%
def cart(product,price):
    print("product is:",product)
    print("cost is:",price)

cart(product="bangles",price=2000)
# Out:
# product is: bangles
# cost is: 2000

# %%
def cart(product,price):
    print("product is:",product)
    print("cost is:",price)

cart(product="handbag",price=20000)
# Out:
# product is: handbag
# cost is: 20000

# %%
def cart(product,price):
    print("product is:",product)
    print("cost is:",price)

cart(price=20000,product="Mobile")
# Out:
# product is: Mobile
# cost is: 20000

# %%
def cart(product,price=40.0):
  print("product is:",product)
  print("cost is:",price)

cart(product="handbag")
# Out:
# product is: handbag
# cost is: 40.0

# %%
def cart(product,price=40.0):
  print("product is:",product)
  print("cost is:",price)

cart(product="handbag",price=10000)
# Out:
# product is: handbag
# cost is: 10000

# %%
def cart(product="mobile",price=40.0):
  print("product is:",product)
  print("cost is:",price)

cart(product="handbag",price=10000)
# Out:
# product is: handbag
# cost is: 10000

# %%
def m(x):
  print(x)
m(10)
# Out:
# 10

# %%
def add(a,b):
  print(a+b)
add(a=5,b=3)
# Out:
# 8

# %%
def m(*x):
   print(x)
m(10)
# Out:
# (10,)

# %%
def m(*x):
  print(x)
m(10,20,50)
# Out:
# (10, 20, 50)

# %%
def m(*x):
  print(x)
m(10,20,)
# Out:
# (10, 20)

# %%
s=lambda a:a*a
x=s(4)
print(x)
# Out:
# 16

# %%
s=lambda a:a*a
x=s(6)
print(x)
# Out:
# 36

# %%
s=lambda a:a*a
x=s(2)
print(x)
# Out:
# 4

# %%
def square(t):
  return t*t
s=square(2)
print(s)
# Out:
# 4

# %%
def square(t):
  return t*t
s=square(3)
print(s)
# Out:
# 9

# %%
def add(x,y):
  return x+y
b=add(2,5)
print(b)
# Out:
# 7

# %%
add=lambda x,y:x+y
result=add(1,2)
print("The sum of value is:",result)
# Out:
# The sum of value is: 3

# %%
without_gst_cost=[100,200,300,400]
with_gst_cost=map(lambda x:x+10,without_gst_cost)
x=list(with_gst_cost)
print("without gst item cost:",without_gst_cost)
print("with gst item costs:",x)
# Out:
# without gst item cost: [100, 200, 300, 400]
# with gst item costs: [110, 210, 310, 410]

# %%
item_cost=[999,888,1100,1200,1300,777]
gt_thousand=filter(lambda x:x>1000,item_cost)

x=list(gt_thousand)
print("Eligible for discount:",x)
# Out:
# Eligible for discount: [1100, 1200, 1300]

# %%
from functools import reduce
items_cost=[111,222,333,444]
total_cost=reduce(lambda x,y:x+y,items_cost)
print(total_cost)
# Out:
# 1110
