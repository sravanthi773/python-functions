# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/python-functions/blob/main/python_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def display():
  print("welcome to function concept")

display()
# Out:
# welcome to function concept

# %%
def display():
  print("welcome to function concept")

display()
display()
# Out:
# welcome to function concept
# welcome to function concept

# %%
def display():
  print("welcome to function concept")
display()
display()
display()
# Out:
# welcome to function concept
# welcome to function concept
# welcome to function concept

# %%
def first():
  print("this is first function")

def second():
  print("this is second function")

first()
second()
# Out:
# this is first function
# this is second function

# %%
def first():
  print("this is first function")

def second():
  print("this is second function")
second()
first()
# Out:
# this is second function
# this is first function

# %%
def m1():
  print(" first function")

def m2():
  print(" second function")

m1()
m2()
# Out:
#  first function
#  second function

# %%
def m1():
  print(" first function")
  m2()
def m2():
  print(" second function")

m1()
# Out:
#  first function
#  second function

# %%
def display():
  print("welcome to function which having no parameters")
display()
# Out:
# welcome to function which having no parameters

# %%
def testing(a):
  print("one parameterised function:",a)
testing(10)
# Out:
# one parameterised function: 10

# %%
def testing(a):
  print("one parameterised function:",a)
testing(10.56)
# Out:
# one parameterised function: 10.56

# %%
def testing(a):
  print("one parameterised function:",a)
testing("daniel")
# Out:
# one parameterised function: daniel

# %%
def testing(a,b):
  print("two parameterised function:",a,b)

testing(10,20)
# Out:
# two parameterised function: 10 20

# %%
def addition(a,b):
    print("addition of twovalues:",(a+b))

addition(10,20)
# Out:
# addition of twovalues: 30

# %%
def subtract(a,b):
    print("subtract of twovalues:",(a-b))

subtract(10,20)
# Out:
# subtract of twovalues: -10

# %%
def multiply(a,b):
    print("multiply of twovalues:",(a*b))

multiply(10,20)
# Out:
# multiply of twovalues: 200

# %%
def balance():
  print("my bank balance is:")
balance()
# Out:
# my bank balance is:

# %%
def balance():
  print("my bank balance is:")
  return 100
balance()
# Out:
# my bank balance is:
# 100

# %%
def balance():
  print("my bank balance is:")
  return 100

b=balance()
print(b)
# Out:
# my bank balance is:
# 100

# %%
def balance():
  return 100

b=balance()
if b==0:
   print("balance is:",b)
elif b<=0:
  print("balance is:",b,"negative please deposit")
else:
  print("balance is:",b)
# Out:
# balance is: 100

# %%
def balance():
  return 0

b=balance()
if b==0:
   print("balance is:",b)
elif b<=0:
  print("balance is:",b,"negative please deposit")
else:
  print("balance is:",b)
# Out:
# balance is: 0

# %%
def balance():
  return -10

b=balance()
if b==0:
   print("balance is:",b)
elif b<=0:
  print("balance is:",b,"negative please deposit")
else:
  print("balance is:",b)
# Out:
# balance is: -10 negative please deposit

# %%
def balance():
  print("my bank balance is:")
  return 100
print(balance())
# Out:
# my bank balance is:
# 100

# %%
def m1():
  print("this function is returning nothing")

x=m1()
print(x)
# Out:
# this function is returning nothing
# None

# %%
def m1():
    a=10
    b=20
    return a,b

x,y=m1()

print("first value is:",x)
print("second value is:",y)
# Out:
# first value is: 10
# second value is: 20

# %%
def m1():
    a=10
    b=20
    c=30
    return a,b,c

x,y,z=m1()

print("first value is:",x)
print("second value is:",y)
print("third value is:",z)
# Out:
# first value is: 10
# second value is: 20
# third value is: 30

# %%
def m1():
    a=10
    b=20
    c=30
    return a,b,c

x=m1()

print("all values:",x)
# Out:
# all values: (10, 20, 30)

# %%
def add(x,y,z):
     result=x+y+z
     return result
r=add(10,20,30)

print("addition of values:",r)
# Out:
# addition of values: 60
